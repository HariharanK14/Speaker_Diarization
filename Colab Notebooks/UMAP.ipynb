# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !pip install pyannote.core
# Out:
# Collecting pyannote.core
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core) (2.4.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core) (1.23.5)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core) (1.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core) (4.5.0)
# Installing collected packages: pyannote.core
# Successfully installed pyannote.core-5.0.0

# %%
# !pip install speechbrain
# Out:
# Collecting speechbrain
#   Downloading speechbrain-0.5.15-py3-none-any.whl (553 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.8/553.8 kB 5.2 MB/s eta 0:00:00
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from speechbrain) (23.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.11.2)
# Collecting sentencepiece (from speechbrain)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.0.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.0.2+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from speechbrain) (4.66.1)
# Collecting huggingface-hub (from speechbrain)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->speechbrain) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->speechbrain) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (6.0.1)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.17.33-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 15.1 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->speechbrain) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Installing collected packages: sentencepiece, ruamel.yaml.clib, ruamel.yaml, huggingface-hub, hyperpyyaml, speechbrain
# Successfully installed huggingface-hub-0.17.3 hyperpyyaml-1.2.2 ruamel.yaml-0.17.33 ruamel.yaml.clib-0.2.7 sentencepiece-0.1.99 speechbrain-0.5.15

# %%
# !pip install rich -qq

# %%
# !pip install git+https://github.com/ssmilin/pyannote-audio.git@develop
# Out:
# Collecting git+https://github.com/ssmilin/pyannote-audio.git@develop
#   Cloning https://github.com/ssmilin/pyannote-audio.git (to revision develop) to /tmp/pip-req-build-k2wxtjpf
#   Running command git clone --filter=blob:none --quiet https://github.com/ssmilin/pyannote-audio.git /tmp/pip-req-build-k2wxtjpf
#   Resolved https://github.com/ssmilin/pyannote-audio.git to commit 04aaaf68eb0dbb252d3d05d92b723e0520e8fe8d
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.17.3)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.0.9.post0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (5.0.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (5.0.1)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (3.2.1)
# Requirement already satisfied: pyannote.pipeline>=2.3 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (3.0.1)
# Requirement already satisfied: pytorch_metric_learning>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.3.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (13.5.2)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (3.0.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.12.1)
# Requirement already satisfied: speechbrain>=0.5.14 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.5.15)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.6.2.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.0.1+cu118)
# Requirement already satisfied: torch_audiomentations>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.11.0)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.0.2+cu118)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==2.1.1) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==2.1.1) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (23.1)
# Requirement already satisfied: Jinja2<5.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (3.1.2)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (1.3.0)
# Requirement already satisfied: backoff<4.0,>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (2.2.1)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (4.11.2)
# Requirement already satisfied: click<10.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (8.1.7)
# Requirement already satisfied: croniter<1.5.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (1.4.1)
# Requirement already satisfied: dateutils<2.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.6.12)
# Requirement already satisfied: deepdiff<8.0,>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (6.5.0)
# Requirement already satisfied: fastapi<2.0,>=0.92.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.103.2)
# Requirement already satisfied: inquirer<5.0,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (3.1.3)
# Requirement already satisfied: lightning-cloud>=0.5.38 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.5.39)
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.9.0)
# Requirement already satisfied: psutil<7.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (5.9.5)
# Requirement already satisfied: pydantic<2.2.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (1.10.12)
# Requirement already satisfied: python-multipart<2.0,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.0.6)
# Requirement already satisfied: starlette in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.27.0)
# Requirement already satisfied: starsessions<2.0,>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (1.3.0)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (5.7.1)
# Requirement already satisfied: urllib3<4.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (2.0.4)
# Requirement already satisfied: uvicorn<2.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (0.23.2)
# Requirement already satisfied: websocket-client<3.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (1.6.2)
# Requirement already satisfied: websockets<13.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (11.0.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==2.1.1) (2.0.9.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==2.1.1) (4.9.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==2.1.1) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==2.1.1) (1.11.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=5.0.1->pyannote.audio==2.1.1) (1.5.3)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=5.0.1->pyannote.audio==2.1.1) (0.9.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==2.1.1) (1.2.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==2.1.1) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==2.1.1) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==2.1.1) (3.7.1)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==2.1.1) (1.12)
# Requirement already satisfied: optuna>=3.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (3.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio==2.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio==2.1.1) (2.16.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->pyannote.audio==2.1.1) (1.15.1)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.10/dist-packages (from speechbrain>=0.5.14->pyannote.audio==2.1.1) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain>=0.5.14->pyannote.audio==2.1.1) (1.3.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain>=0.5.14->pyannote.audio==2.1.1) (0.1.99)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX>=2.6->pyannote.audio==2.1.1) (3.20.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->pyannote.audio==2.1.1) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->pyannote.audio==2.1.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->pyannote.audio==2.1.1) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->pyannote.audio==2.1.1) (16.0.6)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.10.1)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow<3.0,>=1.2.0->lightning>=2.0.1->pyannote.audio==2.1.1) (2.8.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow<3.0,>=1.2.0->lightning>=2.0.1->pyannote.audio==2.1.1) (2.8.19.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<6.0,>=4.8.0->lightning>=2.0.1->pyannote.audio==2.1.1) (2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio==2.1.1) (2.21)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateutils<2.0->lightning>=2.0.1->pyannote.audio==2.1.1) (2023.3.post1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from deepdiff<8.0,>=5.7.0->lightning>=2.0.1->pyannote.audio==2.1.1) (4.1.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi<2.0,>=0.92.0->lightning>=2.0.1->pyannote.audio==2.1.1) (3.7.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (3.8.5)
# Requirement already satisfied: blessed>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio==2.1.1) (1.20.0)
# Requirement already satisfied: python-editor>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio==2.1.1) (1.0.4)
# Requirement already satisfied: readchar>=3.0.6 in /usr/local/lib/python3.10/dist-packages (from inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio==2.1.1) (4.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<5.0->lightning>=2.0.1->pyannote.audio==2.1.1) (2.1.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (3.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.3.6)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (1.0.5)
# Requirement already satisfied: pyjwt in /usr/lib/python3/dist-packages (from lightning-cloud>=0.5.38->lightning>=2.0.1->pyannote.audio==2.1.1) (2.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from lightning-cloud>=0.5.38->lightning>=2.0.1->pyannote.audio==2.1.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio==2.1.1) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (3.1.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (2.0.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (3.2.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from starsessions<2.0,>=1.2.1->lightning>=2.0.1->pyannote.audio==2.1.1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.1->pyannote.metrics>=3.2->pyannote.audio==2.1.1) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.10/dist-packages (from torch-pitch-shift>=1.2.2->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (1.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote.audio==2.1.1) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.2.1->pyannote.database>=5.0.1->pyannote.audio==2.1.1) (1.5.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn<2.0->lightning>=2.0.1->pyannote.audio==2.1.1) (0.14.0)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /usr/local/lib/python3.10/dist-packages (from hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==2.1.1) (0.17.33)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub>=0.13.0->pyannote.audio==2.1.1) (1.3.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (1.2.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi<2.0,>=0.92.0->lightning>=2.0.1->pyannote.audio==2.1.1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi<2.0,>=0.92.0->lightning>=2.0.1->pyannote.audio==2.1.1) (1.1.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning>=2.0.1->pyannote.audio==2.1.1) (0.2.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.6.0->torch_audiomentations>=0.11.0->pyannote.audio==2.1.1) (3.10.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==2.1.1) (0.2.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.1->pyannote.pipeline>=2.3->pyannote.audio==2.1.1) (2.0.2)

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop

# %%
# !python setup.py install
# Out:
# /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:955: SetuptoolsDeprecationWarning: The namespace_packages parameter is deprecated.
# !!
#
#         ********************************************************************************
#         Please replace its usage with implicit namespaces (PEP 420).
#
#         See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages for details.
#         ********************************************************************************
#
# !!
#   ep.load()(self, ep.name, value)
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing pyannote.database.egg-info/PKG-INFO
# writing dependency_links to pyannote.database.egg-info/dependency_links.txt
# writing entry points to pyannote.database.egg-info/entry_points.txt
# writing namespace_packages to pyannote.database.egg-info/namespace_packages.txt
# writing requirements to pyannote.database.egg-info/requires.txt
# writing top-level names to pyannote.database.egg-info/top_level.txt
# /usr/local/lib/python3.10/dist-packages/setuptools/command/sdist.py:119: SetuptoolsDeprecationWarning: `build_py` command does not inherit from setuptools' `build_py`.
# !!
#
#         ********************************************************************************
#         Custom 'build_py' does not implement 'get_data_files_without_manifest'.
#         Please extend command classes from setuptools instead of distutils.
#
#         See https://peps.python.org/pep-0632/ for details.
#         ********************************************************************************
#
# !!
#   self._add_data_files(self._safe_data_files(build_py))
# reading manifest file 'pyannote.database.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'pyannote.database.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# UPDATING build/lib/pyannote/database/_version.py
# set build/lib/pyannote/database/_version.py to '0+unknown'
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pyannote
# copying build/lib/pyannote/__init__.py -> build/bdist.linux-x86_64/egg/pyannote
# creating build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/cli.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/registry.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/loader.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/file_finder.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/util.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/__init__.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/database.py -> build/bdist.linux-x86_64/egg/pyannote/database
# creating build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/collection.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/speaker_recognition.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/speaker_verification.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/protocol.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/__init__.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/speaker_diarization.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/speaker_identification.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/speaker_spotting.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/protocol/segmentation.py -> build/bdist.linux-x86_64/egg/pyannote/database/protocol
# copying build/lib/pyannote/database/custom.py -> build/bdist.linux-x86_64/egg/pyannote/database
# copying build/lib/pyannote/database/_version.py -> build/bdist.linux-x86_64/egg/pyannote/database
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/cli.py to cli.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/registry.py to registry.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/loader.py to loader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/file_finder.py to file_finder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/util.py to util.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/database.py to database.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/collection.py to collection.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/speaker_recognition.py to speaker_recognition.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/speaker_verification.py to speaker_verification.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/protocol.py to protocol.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/speaker_diarization.py to speaker_diarization.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/speaker_identification.py to speaker_identification.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/speaker_spotting.py to speaker_spotting.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/protocol/segmentation.py to segmentation.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/custom.py to custom.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyannote/database/_version.py to _version.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/namespace_packages.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyannote.database.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/pyannote.database-0+unknown-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pyannote.database-0+unknown-py3.10.egg
# Copying pyannote.database-0+unknown-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding pyannote.database 0+unknown to easy-install.pth file
# Installing pyannote-database script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/pyannote.database-0+unknown-py3.10.egg
# Processing dependencies for pyannote.database==0+unknown
# Searching for typer==0.9.0
# Best match: typer 0.9.0
# Adding typer 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pandas==1.5.3
# Best match: pandas 1.5.3
# Adding pandas 1.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyannote.core==5.0.0
# Best match: pyannote.core 5.0.0
# Adding pyannote.core 5.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for rich==13.5.2
# Best match: rich 13.5.2
# Adding rich 13.5.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for shellingham==1.5.3
# Best match: shellingham 1.5.3
# Adding shellingham 1.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for colorama==0.4.6
# Best match: colorama 0.4.6
# Adding colorama 0.4.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for click==8.1.7
# Best match: click 8.1.7
# Adding click 8.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pytz==2023.3.post1
# Best match: pytz 2023.3.post1
# Adding pytz 2023.3.post1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.11.2
# Best match: scipy 1.11.2
# Adding scipy 1.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sortedcontainers==2.4.0
# Best match: sortedcontainers 2.4.0
# Adding sortedcontainers 2.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pygments==2.16.1
# Best match: Pygments 2.16.1
# Adding Pygments 2.16.1 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for markdown-it-py==3.0.0
# Best match: markdown-it-py 3.0.0
# Adding markdown-it-py 3.0.0 to easy-install.pth file
# Installing markdown-it script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for mdurl==0.1.2
# Best match: mdurl 0.1.2
# Adding mdurl 0.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for pyannote.database==0+unknown

# %%
# !PYANNOTE_DATABASE_CONFIG="/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml" pyannote-database info SRM.SpeakerDiarization.mini
# Out:
# 2023-10-03 04:16:25.782105: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-03 04:16:29.388867: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# train
#    80 files
#    4h33m annotated
#    3h15m of speech (72%)
#    22 speakers
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# development
#    10 files
#    0h34m annotated
#    0h25m of speech (75%)
#    17 speakers
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py:140: UserWarning: Existing precomputed key "annotation" has been modified by a preprocessor.
#   warnings.warn(msg.format(key=key))
# test
#    10 files
#    0h35m annotated
#    0h27m of speech (78%)
#    18 speakers

# %%
# !pip install spectralcluster
# Out:
# Collecting spectralcluster
#   Downloading spectralcluster-0.2.21-py3-none-any.whl (31 kB)
# Installing collected packages: spectralcluster
# Successfully installed spectralcluster-0.2.21

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main

# %%
# !python umap.30.9.py
# Out:
# 2023-10-03 04:20:13.531360: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-03 04:20:14.799275: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# Downloading (…)lve/main/config.yaml: 100% 500/500 [00:00<00:00, 2.25MB/s]
# Downloading pytorch_model.bin: 100% 17.7M/17.7M [00:00<00:00, 135MB/s]
# Downloading (…)/2022.07/config.yaml: 100% 318/318 [00:00<00:00, 1.59MB/s]
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.9.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../../../../../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu118. Bad things might happen unless you revert torch to 1.x.
# Downloading (…)ain/hyperparams.yaml: 100% 1.92k/1.92k [00:00<00:00, 9.22MB/s]
# Downloading embedding_model.ckpt: 100% 83.3M/83.3M [00:00<00:00, 291MB/s]
# Downloading (…)an_var_norm_emb.ckpt: 100% 1.92k/1.92k [00:00<00:00, 8.98MB/s]
# Downloading classifier.ckpt: 100% 5.53M/5.53M [00:00<00:00, 170MB/s]
# Downloading (…)in/label_encoder.txt: 100% 129k/129k [00:00<00:00, 8.45MB/s]
# speechbrain/spkrec-ecapa-voxceleb
# /n
# Processing file: conversation1011
# Processing file: conversation1014
# Processing file: conversation1026
# Processing file: conversation1034
# Processing file: conversation1039
# Processing file: conversation1050
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/umap.30.9.py", line 22, in <module>
#     for file in dataset.test():
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py", line 375, in subset_helper
#     yield self.preprocess(file)
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py", line 341, in preprocess
#     return ProtocolFile(current_file, lazy=self.preprocessors)
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py", line 88, in __init__
#     self._store[key] = precomputed[key]
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py", line 134, in __getitem__
#     value = self.lazy[key](self)
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/custom.py", line 106, in load
#     path = resolve_path(Path(template.format(**abs(current_file))), database_yml)
#   File "/usr/local/lib/python3.10/dist-packages/pyannote/database/custom.py", line 144, in resolve_path
#     if path.is_file():
#   File "/usr/lib/python3.10/pathlib.py", line 1322, in is_file
#     return S_ISREG(self.stat().st_mode)
#   File "/usr/lib/python3.10/pathlib.py", line 1097, in stat
#     return self._accessor.stat(self, follow_symlinks=follow_symlinks)
# OSError: [Errno 107] Transport endpoint is not connected: '../uems/test/conversation1060.uem'
